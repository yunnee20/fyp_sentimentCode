# %% [markdown]
# # Import every functions

# %%
import sounddevice as sd
import numpy as np
import librosa
import cv2
import mediapipe as mp
import pynput
from pynput import keyboard
from pythonosc.udp_client import SimpleUDPClient

# %%
import face
from face import face_trigger

result = face.face_trigger(face_start=True, voice_score=60, text_score=65, camera_index=1, show=True)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 2
#       1 import face
# ----> 2 from face import face_trigger
#       4 result = face.face_trigger(face_start=True, voice_score=60, text_score=65, camera_index=1, show=True)
#       5 print(result)
#
# ImportError: cannot import name 'face_trigger' from 'face' (c:\Users\Yun Nee\OneDrive\Desktop\UK\UAL\Year3\FYP_term2\fyp_sentimentCode\face.py)
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# ...

# %%
from pynput import keyboard
def on_press(key):
    global capture_now

    if key == keyboard.Key.space:   # press SPACE to capture
        face.face_start = True
        print("start")
 
    if key == keyboard.Key.esc:
        face.face_start = False
        print("stop")

listener = keyboard.Listener(on_press=on_press)
listener.start()

while True: 
    face.hello()
    # if not face.ret:
    #     break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 17
#      14 listener.start()
#      16 while True:
# ---> 17     face.hello()
#      18     # if not face.ret:
#      19     #     break
#
# AttributeError: module 'face' has no attribute 'hello'
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# ...

# %%
# import everything first 

# ------------------
# STATE 01 : WELCOME
# AI: hey welcome to the test...some instructions, if youre ready pls say "ready"
# user: ready
# ------------------
# trigger listening to "ready"

# ---------------------
# STATE 02 : QUESTION 1
# AI: This is the first scenario
# AI: "You are a student who has just received feedback on your assignment. The feedback is quite negative and you feel disappointed. + video
# How do you react to this feedback?
# ---------------------

# while true : 
# trigger listening to user response
# trigger face 
# trigger

# %%
# from pythonosc.udp_client import SimpleUDPClient

def sendingOSC(label, name):
    client = SimpleUDPClient("127.0.0.1", 8000)
    client.send_message(label, name)
# send OSC message to touchdesigner

# %%
# Out:
# c:\Users\Yun Nee\miniconda3\envs\fyppro\python.exe
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# ...
