# %% [markdown]
# # Import every functions

# %%
import sounddevice as sd
import numpy as np
import librosa
import cv2
import mediapipe as mp
import pynput
from pynput import keyboard
from pythonosc.udp_client import SimpleUDPClient

# %%
import face
from face import face_trigger

result = face.face_trigger(face_start=True, voice_score=60, text_score=65, camera_index=1, show=True)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 2
#       1 import face
# ----> 2 from face import face_trigger
#       4 result = face.face_trigger(face_start=True, voice_score=60, text_score=65, camera_index=1, show=True)
#       5 print(result)
#
# ImportError: cannot import name 'face_trigger' from 'face' (c:\Users\Yun Nee\OneDrive\Desktop\UK\UAL\Year3\FYP_term2\fyp_sentimentCode\face.py)
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstartstartstartstart
# start
# start
# start
# start
#
#
# start
#
# start
# start
#
# start

# %%
from pynput import keyboard
def on_press(key):
    global capture_now

    if key == keyboard.Key.space:   # press SPACE to capture
        face.face_start = True
        print("start")
 
    if key == keyboard.Key.esc:
        face.face_start = False
        print("stop")

listener = keyboard.Listener(on_press=on_press)
listener.start()

while True: 
    face.hello()
    # if not face.ret:
    #     break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 17
#      14 listener.start()
#      16 while True:
# ---> 17     face.hello()
#      18     # if not face.ret:
#      19     #     break
#
# AttributeError: module 'face' has no attribute 'hello'
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stopstop
#
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start

# %%
# import everything first 

# ------------------
# STATE 01 : WELCOME
# AI: hey welcome to the test...some instructions, if youre ready pls say "ready"
# user: ready
# ------------------
# trigger listening to "ready"

# ---------------------
# STATE 02 : QUESTION 1
# AI: This is the first scenario
# AI: "You are a student who has just received feedback on your assignment. The feedback is quite negative and you feel disappointed. + video
# How do you react to this feedback?
# ---------------------

# while true : 
# trigger listening to user response
# trigger face 
# trigger

# %%
# from pythonosc.udp_client import SimpleUDPClient

def sendingOSC(label, name):
    client = SimpleUDPClient("127.0.0.1", 8000)
    client.send_message(label, name)
# send OSC message to touchdesigner

# %%
# Out:
# c:\Users\Yun Nee\miniconda3\envs\fyppro\python.exe
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
# start
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# startstart
#
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start

# %%
import pygame
import time

pygame.mixer.init()

def play_audio(path, wait=False, volume=0.8):
    sound = pygame.mixer.Sound(path)
    sound.set_volume(volume)
    channel = sound.play()

    if wait:
        while channel.get_busy():
            time.sleep(0.05)


play_audio("audio/perfect.mp3")
# Out:
# c:\Users\Yun Nee\miniconda3\envs\fyppro\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Out:
# Press ENTER when audience is ready.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from scene_controller import run_scene_flow
# ----> 3 results = run_scene_flow()
#       4 print(results)
#
# File c:\Users\Yun Nee\OneDrive\Desktop\UK\UAL\Year3\FYP_term2\fyp_sentimentCode\scene_controller.py:84, in run_scene_flow()
#      81 wait_for_key(["enter"])
#      83 # later play ready audio here
# ---> 84 play_audio("audio/ready.mp3", wait=True)
#      86 while remaining_scenes:
#      87     scene_id = random.choice(remaining_scenes)
#
# File c:\Users\Yun Nee\OneDrive\Desktop\UK\UAL\Year3\FYP_term2\fyp_sentimentCode\audioTrigger.py:7, in play_audio(path, wait, volume)
#       6 def play_audio(path, wait=False, volume=0.8):
# ----> 7     sound = pygame.mixer.Sound(path)
#       8     sound.set_volume(volume)
#       9     channel = sound.play()
#
# FileNotFoundError: No file 'audio/ready.mp3' found in working directory 'c:\Users\Yun Nee\OneDrive\Desktop\UK\UAL\Year3\FYP_term2\fyp_sentimentCode'.

# %%
from PIL import Image, ImageDraw, ImageFont
from datetime import datetime
import os
import platform
import subprocess

DPI = 300
WIDTH_IN = 1.97
HEIGHT_IN = 3.94

width = int(WIDTH_IN * DPI)
height = int(HEIGHT_IN * DPI)

scale = width / 215

def S(v):
    return int(v * scale)


def draw_dashed_line(draw, x1, y, x2, dash=6, gap=6):
    x = x1
    while x < x2:
        draw.line((x, y, min(x + S(dash), x2), y), fill=0, width=S(1))
        x += S(dash + gap)


def draw_fake_barcode(draw, x, y, w, h):
    pattern = [
        1, 2, 1, 3, 2, 1, 4, 1,
        2, 3, 1, 1, 3, 2, 4, 1,
        1, 3, 2, 1, 4, 2, 1, 3,
        1, 2, 2, 4, 1, 3, 1, 2,
        4, 1, 1, 2, 3, 1, 2, 1
    ]

    current_x = x

    while current_x < x + w:
        for i, bar_w in enumerate(pattern):
            bar_w = S(bar_w)

            if i % 2 == 0:
                draw.rectangle(
                    (current_x, y, current_x + bar_w, y + h),
                    fill=0
                )

            current_x += bar_w

            if current_x >= x + w:
                break


def generate_receipt(data):
    img = Image.new("L", (width, height), 255)
    draw = ImageDraw.Draw(img)

    # side borders
    border_w = S(3)

    draw.rectangle(
        (0, 0, border_w, height),
        fill=0
    )

    draw.rectangle(
        (width - border_w, 0, width, height),
        fill=0
    )

    padding = S(20)

    font_title = ImageFont.truetype("mat/jbm_extrabold.ttf", S(16))
    font_sub = ImageFont.truetype("mat/jbm_bold.ttf", S(12))
    font_body = ImageFont.truetype("mat/jbm_regular.ttf", S(10))

    y = S(10)

    # top thick line
    draw.line((padding, y, width - padding, y), fill=0, width=S(3))
    y += S(10)

    # title block
    draw.rectangle((padding, y, width - padding, y + S(92)), fill=0)

    draw.text((S(43), y + S(17)), "WHEN AI CLAIMS", font=font_title, fill=255)
    draw.text((S(43), y + S(37)), "TO KNOW US TOO", font=font_title, fill=255)
    draw.text((S(76), y + S(57)), "CLEARLY", font=font_title, fill=255)

    y += S(102)

    # title bottom line
    draw.line((padding, y, width - padding, y), fill=0, width=S(3))
    y += S(12)

    # score
    draw.text(
        (padding, y),
        f"SCORE: {data['score']:.0f}% SUBOPTIMAL",
        font=font_sub,
        fill=0
    )

    y += S(22)
    draw.line((padding, y, width - padding, y), fill=0, width=S(3))
    y += S(10)

    lineheight = S(15)

    draw.text((padding, y), f"Valence: {data['valence']:.0f}", font=font_body, fill=0)
    y += lineheight
    draw.text((padding, y), f"Thinking: {data['thinking']:.3f}", font=font_body, fill=0)
    y += lineheight
    draw.text((padding, y), f"Arousal: {data['arousal']:.2f}", font=font_body, fill=0)
    y += lineheight
    draw.text((padding, y), f"Anxious: {data['anxious']:.3f}", font=font_body, fill=0)

    y += S(22)
    draw_dashed_line(draw, padding, y, width - padding)
    y += S(10)

    draw.text((padding, y), f"Face Score: {data['face']:.1f} %", font=font_body, fill=0)
    y += lineheight
    draw.text((padding, y), f"Voice Score: {data['voice']:.0f} %", font=font_body, fill=0)
    y += lineheight
    draw.text((padding, y), f"Text Score: {data['text']:.0f} %", font=font_body, fill=0)

    y += S(25)
    draw.line((padding, y, width - padding, y), fill=0, width=S(4))
    y += S(12)

    draw.text((padding, y), "Practice Required", font=font_sub, fill=0)

    y += S(20)
    draw_dashed_line(draw, padding, y, width - padding)
    y += S(12)

    # timestamp / ID
    timestamp = datetime.now().strftime("%Y %m %d %H%M%S")
    draw.text((S(30), y-10), f"{timestamp} 1201", font=font_sub, fill=0)
    draw.text((S(25), y+30), "Thank You for participating", font=font_body, fill=0)
    y += S(30)
    draw_dashed_line(draw, padding, y, width - padding)

    y += S(10)

    # barcode
    # draw_fake_barcode(
    #     draw,
    #     x=S(35),
    #     y=y,
    #     w=S(145),
    #     h=S(34)
    # )

    # y += S(42)

    

    # y += S(40)

    draw.text((S(20), y+35), "by Yunnee Tey", font=font_body, fill=0)
    # draw.text((S(40), y+50), "portfolio", font=font_body, fill=100)

    barcode_img = Image.open("mat/qr.png").convert("L")
    barcode_img = barcode_img.resize((S(50), S(50)))
    img.paste(barcode_img, (width - 150- S(20), y-10))

    return img


def save_and_print_receipt(data):
    os.makedirs("receipt", exist_ok=True)

    img = generate_receipt(data)

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"receipt_{timestamp}.pdf"

    img_rgb = img.convert("RGB")
    img_rgb.save(filename, resolution=DPI)

    system = platform.system()

    if system == "Windows":
        os.startfile(filename, "print")

    else:
        print("Unsupported operating system")

    print(f"Printed: {filename}")


# test data
receipt_data = {
    "score": 47,
    "face": 35.76,
    "voice": 60,
    "text": 65,
    "label": "",
    "authenticity": 47,

    "valence": 0,
    "thinking": 17.621,
    "arousal": 56.34,
    "anxious": 70.225,
}


# preview image
img = generate_receipt(receipt_data)
img.show()

# auto print
# save_and_print_receipt(receipt_data)

# %%
generate_receipt(receipt_data)
# Out:
# <PIL.Image.Image image mode=L size=591x1182>

# %%
save_and_print_receipt(receipt_data)
# Out:
# Printed: receipt_20260518_173351.pdf
